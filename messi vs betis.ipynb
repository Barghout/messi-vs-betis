# %%
pip install mplsoccer
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: mplsoccer in c:\users\khale\anaconda3\lib\site-packages (1.1.12)
# Requirement already satisfied: requests in c:\users\khale\anaconda3\lib\site-packages (from mplsoccer) (2.27.1)
# Requirement already satisfied: pillow in c:\users\khale\anaconda3\lib\site-packages (from mplsoccer) (9.0.1)
# Requirement already satisfied: pandas in c:\users\khale\anaconda3\lib\site-packages (from mplsoccer) (1.4.2)
# Requirement already satisfied: scipy in c:\users\khale\anaconda3\lib\site-packages (from mplsoccer) (1.7.3)
# Requirement already satisfied: seaborn in c:\users\khale\anaconda3\lib\site-packages (from mplsoccer) (0.11.2)
# Requirement already satisfied: matplotlib in c:\users\khale\anaconda3\lib\site-packages (from mplsoccer) (3.5.1)
# Requirement already satisfied: numpy in c:\users\khale\anaconda3\lib\site-packages (from mplsoccer) (1.21.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\khale\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\khale\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\khale\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\khale\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\khale\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\khale\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\khale\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplsoccer) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\khale\anaconda3\lib\site-packages (from pandas->mplsoccer) (2021.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khale\anaconda3\lib\site-packages (from requests->mplsoccer) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khale\anaconda3\lib\site-packages (from requests->mplsoccer) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\khale\anaconda3\lib\site-packages (from requests->mplsoccer) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\khale\anaconda3\lib\site-packages (from requests->mplsoccer) (1.26.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch
import seaborn as sns
from mplsoccer import Pitch, FontManager, Sbopen

# %%
df = pd.read_csv('messibetis.csv')

# %%
df.head()
# Out:
#   player  minute  second    x   y  type       outcome  endX  endY
# 0  messi      45       0   50  50  Pass    Successful    40    43
# 1  messi      45      25   63  48  Pass    Successful    75    83
# 2  messi      46       4   74  58  Pass    Successful    71    65
# 3  messi      46       7   76  68  Pass    Successful    95    78
# 4  messi      46      55  100   1  Pass  Unsuccessful    96    38

# %%
df['x'] = df['x']*1.2
df['endX'] = df['endX']*1.2
df['y'] = df['y']*.8
df['endY'] = df['endY']*.8

# %%
df.head()
# Out:
#   player  minute  second      x     y  type       outcome   endX  endY
# 0  messi      45       0   60.0  40.0  Pass    Successful   48.0  34.4
# 1  messi      45      25   75.6  38.4  Pass    Successful   90.0  66.4
# 2  messi      46       4   88.8  46.4  Pass    Successful   85.2  52.0
# 3  messi      46       7   91.2  54.4  Pass    Successful  114.0  62.4
# 4  messi      46      55  120.0   0.8  Pass  Unsuccessful  115.2  30.4

# %%
pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc')
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=False, tight_layout=True)
fig.set_facecolor('#22312b')

pitch.draw(ax=ax)
plt.gca().invert_yaxis()


for x in range(len(df['x'])):
    if df['outcome'][x] == 'Successful':
        plt.plot((df['x'][x],df['endX'][x]),(df['y'][x],df['endY'][x]),color='green')
        plt.scatter(df['x'][x],df['y'][x],color='green')
    if df['outcome'][x] == 'Unsuccessful':
        plt.plot((df['x'][x],df['endX'][x]),(df['y'][x],df['endY'][x]),color='red')
        plt.scatter(df['x'][x],df['y'][x],color='red')

plt.title('Messi Pass Map vs Real Betis',color='white',size=20)
# Out:
# Text(0.5, 1.0, 'Messi Pass Map vs Real Betis')
